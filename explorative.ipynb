# %%
import pandas as pd


df = pd.read_csv("taxonomy.csv")
df["Type"] = df["Type"].apply(lambda x: x.strip())

# %%
import matplotlib.pyplot as plt


grouped = df.groupby(["Language", "Category"]).size().unstack(fill_value=0)

# Plot
grouped.plot(kind="bar", stacked=True, figsize=(10, 7), colormap="tab20b")
plt.xticks(rotation=45)
plt.ylabel("Number of Task Categories")
# plt.title('Number of Task Categories per Language')
plt.legend(
    title="Task Category",
    loc="lower center",
    bbox_to_anchor=(0.5, 1.05),
    ncol=3,
    fancybox=True,
    shadow=True,
)
plt.tight_layout()
plt.show()

# %%
grouped
# Out:
# Category    Commonsense reasoning  Entailment  Language knowledge  \
# Language
# Basque                          3           3                   0
# Catalan                         5           3                   1
# Czech                           0           1                   3
# French                          0           2                   2
# Galician                        0           0                   1
# Norwegian                       2           0                   3
# Portuguese                      0           1                   0
# Spanish                         3           2                   1
# Ukranian                        0           0                   2
#
# Category    Language-specific & world knowledge  Machine translation  \
# Language
# Basque                                        6                    1
# Catalan                                       4                    1
# Czech                                         2                    0
# ...

# %%
grouped = df.groupby(["Language", "Type"]).size().unstack(fill_value=0)

# Plot
grouped.plot(kind="bar", stacked=True, figsize=(10, 7), colormap="tab20b")
plt.xticks(rotation=45)
plt.ylabel("Number of Task Types")
# plt.title('Number of Task Categories per Language')
plt.legend(
    title="Task Type",
    loc="lower center",
    bbox_to_anchor=(0.5, 1.05),
    ncol=3,
    fancybox=True,
    shadow=True,
)
plt.tight_layout()
plt.show()
